# %% [markdown]
# ### Compute SNAP/ACE descriptors from coordinate files
#
# Author: Noé Blassel
#
# I used the package [FitSNAP](https://fitsnap.github.io/) which provides a convenient interface to compute SNAP and ACE descriptors, for the sake of exploration. Warning: getting it to work required a bit of tinkering.
#
# To run, setup FitSNAP and LAMMPS for PACE according to the [instructions](https://fitsnap.github.io/Installation.html#lammps-pace-install), and modify the path in the cell below.

# %%
# !pip install /home/nblassel/Documents/confs/chicago_24/working_group/FitSNAP
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/nblassel/Documents/confs/chicago_24/working_group/FitSNAP
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (1.23.3)
# Requirement already satisfied: scipy in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (1.9.1)
# Requirement already satisfied: scikit-learn in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (1.3.2)
# Requirement already satisfied: psutil in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (5.9.2)
# Requirement already satisfied: pandas in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (2.0.1)
# Requirement already satisfied: tabulate in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (0.9.0)
# Requirement already satisfied: mpi4py in /usr/lib/python3/dist-packages (from fitsnap3==3.1.1.0) (3.0.3)
# Requirement already satisfied: torch in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (2.2.1)
# Requirement already satisfied: sympy in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (1.11.1)
# Requirement already satisfied: pyyaml in /home/nblassel/.local/lib/python3.8/site-packages (from fitsnap3==3.1.1.0) (6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nblassel/.local/lib/python3.8/site-packages (from pandas->fitsnap3==3.1.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/nblassel/.local/lib/python3.8/site-packages (from pandas->fitsnap3==3.1.1.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/nblassel/.local/lib/python3.8/site-packages (from pandas->fitsnap3==3.1.1.0) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/nblassel/.local/lib/python3.8/site-packages (from scikit-learn->fitsnap3==3.1.1.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/nblassel/.local/lib/python3.8/site-packages (from scikit-learn->fitsnap3==3.1.1.0) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in /home/nblassel/.local/lib/python3.8/site-packages (from sympy->fitsnap3==3.1.1.0) (1.3.0)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch->fitsnap3==3.1.1.0) (3.0.12)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (4.11.0)
# Requirement already satisfied: networkx in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (3.1)
# Requirement already satisfied: jinja2 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (3.1.2)
# Requirement already satisfied: fsspec in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/nblassel/.local/lib/python3.8/site-packages (from torch->fitsnap3==3.1.1.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/nblassel/.local/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->fitsnap3==3.1.1.0) (12.3.101)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->fitsnap3==3.1.1.0) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nblassel/.local/lib/python3.8/site-packages (from jinja2->torch->fitsnap3==3.1.1.0) (2.1.1)
# Building wheels for collected packages: fitsnap3
#   Building wheel for fitsnap3 (pyproject.toml) ... done
#   Created wheel for fitsnap3: filename=fitsnap3-3.1.1.0-py3-none-any.whl size=247949 sha256=746c37a11407366529117dfb3e0e0c910219a4ef0f8208faa1a18cd0200dc022
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k6fazuyi/wheels/51/77/a1/aad0c1203a0ec993da8d447e9d121d62593db4fc8f8036aaa5
# Successfully built fitsnap3
# Installing collected packages: fitsnap3
#   Attempting uninstall: fitsnap3
#     Found existing installation: fitsnap3 3.1.1.0
#     Uninstalling fitsnap3-3.1.1.0:
#       Successfully uninstalled fitsnap3-3.1.1.0
# Successfully installed fitsnap3-3.1.1.0

# %%
import pandas as pd

from ase import Atoms
from ase.io import read,write

from ase.visualize import view

from os import listdir
from os.path import join

import numpy as np

import re
from fitsnap3lib.fitsnap import FitSnap
from fitsnap3lib.scrapers.ase_funcs import ase_scraper

# %%
data_dir = "../data/transition_data_pt/"

def read_ase(filename):
    
    return read(
        filename=filename, 
        format="lammps-data", 
        Z_of_type={1: 78}, 
        style="atomic"
    )

# %%
files = listdir(data_dir)

df = pd.DataFrame(columns = ["initial_state","final_state","initial_conf","final_conf","initial_file","final_file"])

for f in files:
    m = re.match('(\d+)_(\d+)_([01])\.dat',f)
    if m is not None:
        state_ini, state_fin, is_final = map(int, m.groups())
        if is_final == 1:
            conf_fin = read_ase(join(data_dir,f))
            conf_ini = read_ase(join(data_dir,f"{state_ini}_{state_fin}_0.dat"))
        df.loc[len(df)]=[state_ini,state_fin,conf_ini,conf_fin,f"{state_ini}_{state_fin}_0.dat",f]

df
# Out:
#       initial_state  final_state
# 0              2458         2514  \
# 1              2417         2418
# 2              1023         1024
# 3               868          869
# 4               540          542
# ...             ...          ...
# 6923           2115         2128
# 6924           2166         1689
# 6925            945          946
# 6926           1723         1735
# 6927           1212         1177
#
#                                            initial_conf
# 0     (Atom('Pt', [16.891824119192098, 10.1507631789...  \
# 1     (Atom('Pt', [11.715215934019668, 16.3911847516...
# 2     (Atom('Pt', [19.207468506917255, 20.3295459034...
# 3     (Atom('Pt', [19.207468506917255, 20.3295459034...
# 4     (Atom('Pt', [19.207468506917255, 20.3295459034...
# ...                                                 ...
# 6923  (Atom('Pt', [19.713114789263727, 20.9530791355...
# 6924  (Atom('Pt', [19.3945175019235, 20.233189112181...
# 6925  (Atom('Pt', [19.3945175019235, 20.233189112181...
# 6926  (Atom('Pt', [8.403605399621133, 15.66192933852...
# 6927  (Atom('Pt', [8.403605399621133, 15.66192933852...
#
#                                              final_conf     initial_file
# 0     (Atom('Pt', [16.853061085379768, 10.1137640799...  2458_2514_0.dat  \
# 1     (Atom('Pt', [11.821776976486966, 16.3676259690...  2417_2418_0.dat
# 2     (Atom('Pt', [19.15307574312301, 20.30019765624...  1023_1024_0.dat
# 3     (Atom('Pt', [19.15307574312301, 20.30019765624...    868_869_0.dat
# 4     (Atom('Pt', [19.15307574312301, 20.30019765624...    540_542_0.dat
# ...                                                 ...              ...
# 6923  (Atom('Pt', [19.767766072487134, 20.8601510259...  2115_2128_0.dat
# 6924  (Atom('Pt', [19.463021736568283, 20.2095783358...  2166_1689_0.dat
# 6925  (Atom('Pt', [19.463021736568283, 20.2095783358...    945_946_0.dat
# 6926  (Atom('Pt', [8.255799203538341, 15.73714546328...  1723_1735_0.dat
# 6927  (Atom('Pt', [8.255799203538341, 15.73714546328...  1212_1177_0.dat
#
#            final_file
# 0     2458_2514_1.dat
# 1     2417_2418_1.dat
# 2     1023_1024_1.dat
# 3       868_869_0.dat
# 4       540_542_0.dat
# ...               ...
# 6923  2115_2128_0.dat
# 6924  2166_1689_1.dat
# 6925    945_946_0.dat
# 6926  1723_1735_1.dat
# 6927  1212_1177_0.dat
#
# [6928 rows x 6 columns]

# %%
ix = 100

view([df.initial_conf[ix],df.final_conf[ix]])

# %% [markdown]
# Here I just use the parameters given in the FitSNAP [tutorial](https://colab.research.google.com/github/FitSNAP/FitSNAP/blob/master/tutorial.ipynb)

# %%
sna_settings =\
{
"BISPECTRUM":
    {
    "numTypes": 1,
    "twojmax": 6,
    "rcutfac": 4.67637,
    "rfac0": 0.99363,
    "rmin0": 0.0,
    "wj": 1.0,
    "radelem": 0.5,
    "type": "Pt",
    "wselfallflag": 0,
    "bzeroflag": 1,
    "bikflag": 1
    },
"CALCULATOR":
    {
    "calculator": "LAMMPSSNAP",
    "energy": 1,
    "force": 0,
    "stress": 0,
    "per_atom_energy": 1
    },
"REFERENCE":
    {
    "units": "metal",
    "atom_style": "atomic",
    "pair_style": "zero 6.0",
    "pair_coeff": "* *"
    }
}

ace_settings = \
{
"ACE":
    {
    "numTypes": 1,
    "ranks": "1 2 3",
    "lmax":  "1 2 2",
    "nmax": "22 2 2",
    "nmaxbase": 22,
    "rcutfac": 4.604694451,
    "lambda": 3.5,
    "type": "Pt",
    "lmin": 0,
    "bzeroflag": 1,
    "bikflag": 1,
    "RPI_heuristic": "root_SO3_span"
    },
"CALCULATOR":
    {
    "calculator": "LAMMPSPACE",
    "energy": 1,
    "force": 0,
    "stress": 0,
    "per_atom_energy": 1
    },
"REFERENCE":
    {
    "units": "metal",
    "atom_style": "atomic",
    "pair_style": "zero 6.0",
    "pair_coeff": "* *"
    }
}

fs_sna = FitSnap(sna_settings, arglist=["--overwrite"])
fs_ace = FitSnap(ace_settings, arglist=["--overwrite"])

# %%
